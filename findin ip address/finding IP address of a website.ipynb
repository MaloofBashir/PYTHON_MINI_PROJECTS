# %%
import socket

# %%
# Host Name
hostname=input("Enter the host name")

# %%
try:
    print(f"IP:{socket.gethostbyname(hostname)}")
except socket.gaierror as er:
    print(f"invalid hostname, Error{er}")
